# %% [markdown]
# # Residual Histogram
# ## Creating an histogram from residual to see queue legnth distribution

# %% [markdown]
# run html

# %%
import numpy as np
import os

path = os.getcwd()
path 
dataset = np.loadtxt(path + "/metrics1a.csv", delimiter=",")
dataset
# Out:
# array([[4.840e+02, 9.800e+01, 7.000e-03, 1.350e-01, 2.000e+01],
#        [1.350e+02, 1.000e+02, 6.700e-03, 1.100e-01, 1.400e+01],
#        [6.270e+02, 8.600e+01, 7.600e-03, 1.275e-01, 3.100e+01],
#        ...,
#        [5.090e+02, 8.800e+01, 7.500e-03, 1.109e-01, 3.900e+01],
#        [6.610e+02, 9.100e+01, 7.500e-03, 2.047e-01, 3.700e+01],
#        [3.370e+02, 9.500e+01, 7.400e-03, 1.137e-01, 4.300e+01]])

# %%
from matplotlib.pyplot import figure
import matplotlib.pyplot as plt
# %matplotlib inline
figure(num=None, figsize=(15, 7), dpi=80, facecolor='w', edgecolor='k')

plt.plot(dataset)
#plt.hist(dataset,bins=50)
plt.gca().set_xscale("log", nonposx='clip')
plt.gca().set_yscale("log", nonposy='clip')
plt.title('rsidual distribution')
plt.xlabel('queue size')
plt.ylabel('auctions');
